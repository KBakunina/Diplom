# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
X = pd.read_csv('/content/drive/MyDrive/diplom/dataset/X.csv')
y = pd.read_csv('/content/drive/MyDrive/diplom/dataset/y.csv')

# %%
columns_to_drop = ['Unnamed: 0']
X.drop(columns=columns_to_drop, inplace=True)
y.drop(columns=columns_to_drop, inplace=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225745 entries, 0 to 225744
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Flow ID                  225745 non-null  int64
#  1    Source IP               225745 non-null  int64
#  2    Source Port             225745 non-null  int64
#  3    Destination IP          225745 non-null  int64
#  4    Destination Port        225745 non-null  int64
#  5    Protocol                225745 non-null  int64
#  6    Timestamp               225745 non-null  int64
#  7    Fwd Packet Length Max   225745 non-null  int64
#  8    Fwd Packet Length Mean  225745 non-null  float64
#  9   Bwd Packet Length Max    225745 non-null  int64
#  10   Bwd Packet Length Min   225745 non-null  int64
#  11   Bwd Packet Length Mean  225745 non-null  float64
#  12   Bwd Packet Length Std   225745 non-null  float64
# ...

# %%
X
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 0         82985          22           443              866              54865
# 1         83017          37            80              866              55054
# 2         83018          37            80              866              55055
# 3         57106          45           443              860              46236
# 4         83023          49           443              866              54863
# ...         ...         ...           ...              ...                ...
# 225740    56764        1925            80              859              61374
# 225741    56768        1925            80              859              61378
# 225742    56765        1925            80              859              61375
# 225743    56856        1983            80              859              61323
# 225744    56863        1986            80              859              61326
#
# ...

# %%
y
# Out:
#         Label
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 225740      0
# 225741      0
# 225742      0
# 225743      0
# 225744      0
#
# [225745 rows x 1 columns]

# %%
X_DDoS1 = X.loc[0:21320]

# %%
X_DDoS1
# Out:
#        Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 0        82985          22           443              866              54865
# 1        83017          37            80              866              55054
# 2        83018          37            80              866              55055
# 3        57106          45           443              860              46236
# 4        83023          49           443              866              54863
# ...        ...         ...           ...              ...                ...
# 21316    33430         426         52204              867                 80
# 21317    33431         426         52205              867                 80
# 21318    33432         426         52206              867                 80
# 21319    33433         426         52207              867                 80
# 21320    33434         426         52208              867                 80
#
# ...

# %%
y_DDoS1 = y.loc[0:21320]

# %%
y_DDoS1
# Out:
#        Label
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 21316      1
# 21317      1
# 21318      1
# 21319      1
# 21320      1
#
# [21321 rows x 1 columns]

# %%
X_DDoS2 = X.loc[21321:30792]

# %%
X_DDoS2
# Out:
#        Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 21321    47018         441           443              870               9377
# 21322    47183         451           443              870               9393
# 21323    47488         478           443              859              58739
# 21324    47557         483           443              859              58574
# 21325    47730         496           443              859              58681
# ...        ...         ...           ...              ...                ...
# 30788    35043         426         53817              867                 80
# 30789    35044         426         53818              867                 80
# 30790    35045         426         53819              867                 80
# 30791    35046         426         53820              867                 80
# 30792    35047         426         53821              867                 80
#
# ...

# %%
y_DDoS2 = y.loc[21321:30792]

# %%
y_DDoS2
# Out:
#        Label
# 21321      0
# 21322      0
# 21323      0
# 21324      0
# 21325      0
# ...      ...
# 30788      1
# 30789      1
# 30790      1
# 30791      1
# 30792      1
#
# [9472 rows x 1 columns]

# %%
X_DDoS3 = X.loc[30793:39916]

# %%
X_DDoS3
# Out:
#        Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 30793    46897         435           443              862              55345
# 30794    46985         438           443              862              44137
# 30795    47033         443            80              857              47190
# 30796    47391         473            80              862              43038
# 30797    47495         479           443              862              56873
# ...        ...         ...           ...              ...                ...
# 39912    36684         426         55458              867                 80
# 39913    36685         426         55459              867                 80
# 39914    36686         426         55460              867                 80
# 39915    36687         426         55461              867                 80
# 39916    36688         426         55462              867                 80
#
# ...

# %%
y_DDoS3 = y.loc[30793:39916]

# %%
y_DDoS3
# Out:
#        Label
# 30793      0
# 30794      0
# 30795      0
# 30796      0
# 30797      0
# ...      ...
# 39912      1
# 39913      1
# 39914      1
# 39915      1
# 39916      1
#
# [9124 rows x 1 columns]

# %%
X_DDoS4 = X.loc[39917:49661]

# %%
X_DDoS4
# Out:
#        Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 39917    46894         435            80              860              42266
# 39918    47296         465           443              860              44548
# 39919    47296         465           443              860              44548
# 39920    47389         473            80              859              58578
# 39921    47388         473            80              859              58577
# ...        ...         ...           ...              ...                ...
# 49657    38362         426         57136              867                 80
# 49658    38363         426         57137              867                 80
# 49659    38364         426         57138              867                 80
# 49660    38365         426         57139              867                 80
# 49661    38366         426         57140              867                 80
#
# ...

# %%
y_DDoS4 = y.loc[39917:49661]

# %%
y_DDoS4
# Out:
#        Label
# 39917      0
# 39918      0
# 39919      0
# 39920      0
# 39921      0
# ...      ...
# 49657      1
# 49658      1
# 49659      1
# 49660      1
# 49661      1
#
# [9745 rows x 1 columns]

# %%
X_DDoS5 = X.loc[49662:59090]

# %%
X_DDoS5
# Out:
#        Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 49662    46889         435            80              859              58946
# 49663    46888         435           443              859              58604
# 49664    46888         435           443              859              58604
# 49665    46896         435           443              862              55340
# 49666    46912         435            80              869               9577
# ...        ...         ...           ...              ...                ...
# 59086    40046         426         58820              867                 80
# 59087    40047         426         58821              867                 80
# 59088    40048         426         58822              867                 80
# 59089    40049         426         58823              867                 80
# 59090    40050         426         58824              867                 80
#
# ...

# %%
y_DDoS5 = y.loc[49662:59090]

# %%
y_DDoS5
# Out:
#        Label
# 49662      0
# 49663      0
# 49664      0
# 49665      0
# 49666      0
# ...      ...
# 59086      1
# 59087      1
# 59088      1
# 59089      1
# 59090      1
#
# [9429 rows x 1 columns]

# %%
X_DDoS6 = X.loc[59091:68664]

# %%
X_DDoS6
# Out:
#        Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 59091    46886         435            80              857              55134
# 59092    46895         435            80              860              42268
# 59093    46967         437           443              857              60820
# 59094    47014         441           443              866              56101
# 59095    47068         444           443              857              52180
# ...        ...         ...           ...              ...                ...
# 68660    41745         426         60519              867                 80
# 68661    41746         426         60520              867                 80
# 68662    41747         426         60521              867                 80
# 68663    41748         426         60522              867                 80
# 68664    41749         426         60523              867                 80
#
# ...

# %%
y_DDoS6 = y.loc[59091:68664]

# %%
y_DDoS6
# Out:
#        Label
# 59091      0
# 59092      0
# 59093      0
# 59094      0
# 59095      0
# ...      ...
# 68660      1
# 68661      1
# 68662      1
# 68663      1
# 68664      1
#
# [9574 rows x 1 columns]

# %%
X_DDoS7 = X.loc[68665:77854]

# %%
X_DDoS7
# Out:
#        Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 68665    46890         435            80              859              58993
# 68666    46891         435           443              860              59892
# 68667    46891         435           443              860              59892
# 68668    46903         435            80              866              56106
# 68669    46910         435            80              869               9570
# ...        ...         ...           ...              ...                ...
# 77850    43411         426         62185              867                 80
# 77851    43412         426         62186              867                 80
# 77852    43413         426         62187              867                 80
# 77853    43414         426         62188              867                 80
# 77854    43415         426         62189              867                 80
#
# ...

# %%
y_DDoS7 = y.loc[68665:77854]

# %%
y_DDoS7
# Out:
#        Label
# 68665      0
# 68666      0
# 68667      0
# 68668      0
# 68669      0
# ...      ...
# 77850      1
# 77851      1
# 77852      1
# 77853      1
# 77854      1
#
# [9190 rows x 1 columns]

# %%
X_DDoS8 = X.loc[77855:86103]

# %%
X_DDoS8
# Out:
#        Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 77855    46882         435            80              857              55038
# 77856    46884         435            80              857              55126
# 77857    46885         435            80              857              55132
# 77858    46883         435            80              857              55124
# 77859    46905         435            80              866              56108
# ...        ...         ...           ...              ...                ...
# 86099    45075         426         63849              867                 80
# 86100    45076         426         63850              867                 80
# 86101    45077         426         63851              867                 80
# 86102    45078         426         63852              867                 80
# 86103    45079         426         63853              867                 80
#
# ...

# %%
y_DDoS8 = y.loc[77855:86103]

# %%
y_DDoS8
# Out:
#        Label
# 77855      0
# 77856      0
# 77857      0
# 77858      0
# 77859      0
# ...      ...
# 86099      1
# 86100      1
# 86101      1
# 86102      1
# 86103      1
#
# [8249 rows x 1 columns]

# %%
X_DDoS9 = X.loc[86104:94480]

# %%
X_DDoS9
# Out:
#        Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 86104    46881         435           443              857              42196
# 86105    46966         437           443              857              60818
# 86106    46975         437           443              866              56132
# 86107    46978         438           443              857              47030
# 86108    47013         441           443              866              56096
# ...        ...         ...           ...              ...                ...
# 94476    46698         426         65472              867                 80
# 94477    46699         426         65473              867                 80
# 94478    46700         426         65474              867                 80
# 94479    46701         426         65475              867                 80
# 94480    46702         426         65476              867                 80
#
# ...

# %%
y_DDoS9 = y.loc[86104:94480]

# %%
y_DDoS9
# Out:
#        Label
# 86104      0
# 86105      0
# 86106      0
# 86107      0
# 86108      0
# ...      ...
# 94476      1
# 94477      1
# 94478      1
# 94479      1
# 94480      1
#
# [8377 rows x 1 columns]

# %%
X_DDoS10 = X.loc[94481:102484]

# %%
X_DDoS10
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 94481     46980         438           443              859              58588
# 94482     47120         449           443              859              58566
# 94483     47293         465           443              859              58600
# 94484     47490         479           443              859              58544
# 94485     47558         483           443              859              58576
# ...         ...         ...           ...              ...                ...
# 102480    14812         426         27632              867                 80
# 102481    14813         426         27633              867                 80
# 102482    14814         426         27634              867                 80
# 102483    14815         426         27635              867                 80
# 102484    14816         426         27636              867                 80
#
# ...

# %%
y_DDoS10 = y.loc[94481:102484]

# %%
y_DDoS10
# Out:
#         Label
# 94481       0
# 94482       0
# 94483       0
# 94484       0
# 94485       0
# ...       ...
# 102480      1
# 102481      1
# 102482      1
# 102483      1
# 102484      1
#
# [8004 rows x 1 columns]

# %%
X_DDoS11 = X.loc[102485:110710]

# %%
X_DDoS11
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 102485    47691         491           443              858              58098
# 102486    48264         550           443              866              56153
# 102487    51920         694         46034               15                443
# 102488    52049         694         41794              244                 80
# 102489    52043         694         41782              244                 80
# ...         ...         ...           ...              ...                ...
# 110706    15943         426         28763              867                 80
# 110707    15944         426         28764              867                 80
# 110708    15945         426         28765              867                 80
# 110709    15946         426         28766              867                 80
# 110710    15947         426         28767              867                 80
#
# ...

# %%
y_DDoS11 = y.loc[102485:110710]

# %%
y_DDoS11
# Out:
#         Label
# 102485      0
# 102486      0
# 102487      0
# 102488      0
# 102489      0
# ...       ...
# 110706      1
# 110707      1
# 110708      1
# 110709      1
# 110710      1
#
# [8226 rows x 1 columns]

# %%
X_DDoS12 = X.loc[110711:110945]

# %%
X_DDoS12
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 110711    47646         488            80              858              58077
# 110712    47647         488            80              858              58078
# 110713    64049         694         47837              865                 53
# 110714    63730         694         44690              865                 53
# 110715    52700         694         54414             2073                 80
# ...         ...         ...           ...              ...                ...
# 110941    50916         701         61526              856                 53
# 110942    83410         702         56159             1079               8080
# 110943    46095         703            80              537              64869
# 110944    46099         703            80              537              64873
# 110945    14816         703            80              537              27636
#
# ...

# %%
y_DDoS12 = y.loc[110711:110945]

# %%
y_DDoS12
# Out:
#         Label
# 110711      0
# 110712      0
# 110713      0
# 110714      0
# 110715      0
# ...       ...
# 110941      0
# 110942      0
# 110943      1
# 110944      1
# 110945      1
#
# [235 rows x 1 columns]

# %%
X_DDoS13 = X.loc[110946:119033]

# %%
X_DDoS13
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 110946    32004         703            80              537              50780
# 110947    32003         703            80              537              50779
# 110948    32007         703            80              537              50783
# 110949    32006         703            80              537              50782
# 110950    32005         703            80              537              50781
# ...         ...         ...           ...              ...                ...
# 119029    17222         426         30042              867                 80
# 119030    17223         426         30043              867                 80
# 119031    17224         426         30044              867                 80
# 119032    17225         426         30045              867                 80
# 119033    17226         426         30046              867                 80
#
# ...

# %%
y_DDoS13 = y.loc[110946:119033]

# %%
y_DDoS13
# Out:
#         Label
# 110946      0
# 110947      0
# 110948      0
# 110949      0
# 110950      0
# ...       ...
# 119029      1
# 119030      1
# 119031      1
# 119032      1
# 119033      1
#
# [8088 rows x 1 columns]

# %%
X_DDoS14 = X.loc[119034:128098]

# %%
X_DDoS14
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 119034    47701         492           443              857              46730
# 119035    47789         499           443              858              58092
# 119036    47898         512           443              858              58053
# 119037    48196         537           443              858              58044
# 119038    48225         544           443              858              58073
# ...         ...         ...           ...              ...                ...
# 128094    18655         426         31475              867                 80
# 128095    18656         426         31476              867                 80
# 128096    18657         426         31477              867                 80
# 128097    18658         426         31478              867                 80
# 128098    18659         426         31479              867                 80
#
# ...

# %%
y_DDoS14 = y.loc[119034:128098]

# %%
y_DDoS14
# Out:
#         Label
# 119034      0
# 119035      0
# 119036      0
# 119037      0
# 119038      0
# ...       ...
# 128094      1
# 128095      1
# 128096      1
# 128097      1
# 128098      1
#
# [9065 rows x 1 columns]

# %%
X_DDoS15 = X.loc[128099:137177]

# %%
X_DDoS15
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 128099    47011         440           443              870               9540
# 128100    47057         443           443              870               9557
# 128101    47439         474           443              869               9650
# 128102    47443         474           443              869               9682
# 128103    47444         474           443              869               9683
# ...         ...         ...           ...              ...                ...
# 137173    20271         426         33091              867                 80
# 137174    20273         426         33093              867                 80
# 137175    20274         426         33094              867                 80
# 137176    20275         426         33095              867                 80
# 137177    20276         426         33096              867                 80
#
# ...

# %%
y_DDoS15 = y.loc[128099:137177]

# %%
y_DDoS15
# Out:
#         Label
# 128099      0
# 128100      0
# 128101      0
# 128102      0
# 128103      0
# ...       ...
# 137173      1
# 137174      1
# 137175      1
# 137176      1
# 137177      1
#
# [9079 rows x 1 columns]

# %%
X_DDoS16 = X.loc[137178:146138]

# %%
X_DDoS16
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 137178    47135         451           443              858              58161
# 137179    47419         474           443              859              59122
# 137180    47510         481            80              858              58170
# 137181    47555         483            80              858              58163
# 137182    47653         488            80              860              36366
# ...         ...         ...           ...              ...                ...
# 146134    21922         426         34742              867                 80
# 146135    21923         426         34743              867                 80
# 146136    21924         426         34744              867                 80
# 146137    21925         426         34745              867                 80
# 146138    21926         426         34746              867                 80
#
# ...

# %%
y_DDoS16 = y.loc[137178:146138]

# %%
y_DDoS16
# Out:
#         Label
# 137178      0
# 137179      0
# 137180      0
# 137181      0
# 137182      0
# ...       ...
# 146134      1
# 146135      1
# 146136      1
# 146137      1
# 146138      1
#
# [8961 rows x 1 columns]

# %%
X_DDoS17 = X.loc[146139:154720]

# %%
X_DDoS17
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 146139    47036         443           443              859              59145
# 146140    47121         449           443              859              59112
# 146141    47265         461           443              859              59136
# 146142    47421         474           443              859              59141
# 146143    47420         474           443              859              59140
# ...         ...         ...           ...              ...                ...
# 154716    23555         426         36375              867                 80
# 154717    23556         426         36376              867                 80
# 154718    23557         426         36377              867                 80
# 154719    23558         426         36378              867                 80
# 154720    23559         426         36379              867                 80
#
# ...

# %%
y_DDoS17 = y.loc[146139:154720]

# %%
y_DDoS17
# Out:
#         Label
# 146139      0
# 146140      0
# 146141      0
# 146142      0
# 146143      0
# ...       ...
# 154716      1
# 154717      1
# 154718      1
# 154719      1
# 154720      1
#
# [8582 rows x 1 columns]

# %%
X_DDoS18 = X.loc[154721:164405]

# %%
X_DDoS18
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 154721    47005         440            80              859              59230
# 154722    47010         440           443              870               9539
# 154723    47056         443           443              870               9556
# 154724    47058         443           443              870               9637
# 154725    47184         451           443              870               9634
# ...         ...         ...           ...              ...                ...
# 164401    25211         426         38031              867                 80
# 164402    25212         426         38032              867                 80
# 164403    25213         426         38033              867                 80
# 164404    25214         426         38034              867                 80
# 164405    25215         426         38035              867                 80
#
# ...

# %%
y_DDoS18 = y.loc[154721:164405]

# %%
y_DDoS18
# Out:
#         Label
# 154721      0
# 154722      0
# 154723      0
# 154724      0
# 154725      0
# ...       ...
# 164401      1
# 164402      1
# 164403      1
# 164404      1
# 164405      1
#
# [9685 rows x 1 columns]

# %%
X_DDoS19 = X.loc[164406:173131]

# %%
X_DDoS19
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 164406    47034         443           443              858              58135
# 164407    47035         443           443              858              58172
# 164408    47134         451           443              858              58159
# 164409    47817         503           443              858              58166
# 164410    48241         548           443              858              58171
# ...         ...         ...           ...              ...                ...
# 173127    26841         426         39661              867                 80
# 173128    26842         426         39662              867                 80
# 173129    26843         426         39663              867                 80
# 173130    26844         426         39664              867                 80
# 173131    26845         426         39665              867                 80
#
# ...

# %%
y_DDoS19 = y.loc[164406:173131]

# %%
y_DDoS19
# Out:
#         Label
# 164406      0
# 164407      0
# 164408      0
# 164409      0
# 164410      0
# ...       ...
# 173127      1
# 173128      1
# 173129      1
# 173130      1
# 173131      1
#
# [8726 rows x 1 columns]

# %%
X_DDoS20 = X.loc[173132:184341]

# %%
X_DDoS20
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 173132    46855         432           443              860              34026
# 173133    46858         432           443              860              34048
# 173134    46856         432           443              860              34028
# 173135    46857         432           443              860              34046
# 173136    46873         433           443              860              54774
# ...         ...         ...           ...              ...                ...
# 184337    28460         426         41280              867                 80
# 184338    28461         426         41281              867                 80
# 184339    28462         426         41282              867                 80
# 184340    28463         426         41283              867                 80
# 184341    28464         426         41284              867                 80
#
# ...

# %%
y_DDoS20 = y.loc[173132:184341]

# %%
y_DDoS20
# Out:
#         Label
# 173132      0
# 173133      0
# 173134      0
# 173135      0
# 173136      0
# ...       ...
# 184337      1
# 184338      1
# 184339      1
# 184340      1
# 184341      1
#
# [11210 rows x 1 columns]

# %%
X_DDoS21 = X.loc[184342:193445]

# %%
X_DDoS21
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 184342    46845         432           443              859              59273
# 184343    46845         432           443              859              59273
# 184344    46871         433            80              858              58237
# 184345    46874         433           443              866              56189
# 184346    46919         436            80              858              58225
# ...         ...         ...           ...              ...                ...
# 193441    30065         426         42885              867                 80
# 193442    30066         426         42886              867                 80
# 193443    30067         426         42887              867                 80
# 193444    30068         426         42888              867                 80
# 193445    30069         426         42889              867                 80
#
# ...

# %%
y_DDoS21 = y.loc[184342:193445]

# %%
y_DDoS21
# Out:
#         Label
# 184342      0
# 184343      0
# 184344      0
# 184345      0
# 184346      0
# ...       ...
# 193441      1
# 193442      1
# 193443      1
# 193444      1
# 193445      1
#
# [9104 rows x 1 columns]

# %%
X_DDoS22 = X.loc[193446:197542]

# %%
X_DDoS22
# Out:
#         Flow ID   Source IP   Source Port   Destination IP   Destination Port  \
# 193446    46859         432           443              861              53537
# 193447    46862         432           443              861              53569
# 193448    46860         432           443              861              53560
# 193449    46861         432           443              861              53568
# 193450    46870         433            80              858              58236
# ...         ...         ...           ...              ...                ...
# 197538    30379         426         43199              867                 80
# 197539    30380         426         43200              867                 80
# 197540    30380         426         43200              867                 80
# 197541    30381         426         43201              867                 80
# 197542    30381         426         43201              867                 80
#
# ...

# %%
y_DDoS22 = y.loc[193446:197542]

# %%
y_DDoS22
# Out:
#         Label
# 193446      0
# 193447      0
# 193448      0
# 193449      0
# 193450      0
# ...       ...
# 197538      1
# 197539      1
# 197540      1
# 197541      1
# 197542      1
#
# [4097 rows x 1 columns]

# %%
X_DDoS1.to_csv('X_DDoS1.csv')
y_DDoS1.to_csv('y_DDoS1.csv')

# %%
X_DDoS2.to_csv('X_DDoS2.csv')
y_DDoS2.to_csv('y_DDoS2.csv')

# %%
X_DDoS3.to_csv('X_DDoS3.csv')
y_DDoS3.to_csv('y_DDoS3.csv')

# %%
X_DDoS4.to_csv('X_DDoS4.csv')
y_DDoS4.to_csv('y_DDoS4.csv')

# %%
X_DDoS5.to_csv('X_DDoS5.csv')
y_DDoS5.to_csv('y_DDoS5.csv')

# %%
X_DDoS6.to_csv('X_DDoS6.csv')
y_DDoS6.to_csv('y_DDoS6.csv')

# %%
X_DDoS7.to_csv('X_DDoS7.csv')
y_DDoS7.to_csv('y_DDoS7.csv')

# %%
X_DDoS8.to_csv('X_DDoS8.csv')
y_DDoS8.to_csv('y_DDoS8.csv')

# %%
X_DDoS9.to_csv('X_DDoS9.csv')
y_DDoS9.to_csv('y_DDoS9.csv')

# %%
X_DDoS10.to_csv('X_DDoS10.csv')
y_DDoS10.to_csv('y_DDoS10.csv')

# %%
X_DDoS11.to_csv('X_DDoS11.csv')
y_DDoS11.to_csv('y_DDoS11.csv')

# %%
X_DDoS12.to_csv('X_DDoS12.csv')
y_DDoS12.to_csv('y_DDoS12.csv')

# %%
X_DDoS13.to_csv('X_DDoS13.csv')
y_DDoS13.to_csv('y_DDoS13.csv')

# %%
X_DDoS14.to_csv('X_DDoS14.csv')
y_DDoS14.to_csv('y_DDoS14.csv')

# %%
X_DDoS15.to_csv('X_DDoS15.csv')
y_DDoS15.to_csv('y_DDoS15.csv')

# %%
X_DDoS16.to_csv('X_DDoS16.csv')
y_DDoS16.to_csv('y_DDoS16.csv')

# %%
X_DDoS17.to_csv('X_DDoS17.csv')
y_DDoS17.to_csv('y_DDoS17.csv')

# %%
X_DDoS18.to_csv('X_DDoS18.csv')
y_DDoS18.to_csv('y_DDoS18.csv')

# %%
X_DDoS19.to_csv('X_DDoS19.csv')
y_DDoS19.to_csv('y_DDoS19.csv')

# %%
X_DDoS20.to_csv('X_DDoS20.csv')
y_DDoS20.to_csv('y_DDoS20.csv')

# %%
X_DDoS21.to_csv('X_DDoS21.csv')
y_DDoS21.to_csv('y_DDoS21.csv')

# %%
X_DDoS22.to_csv('X_DDoS22.csv')
y_DDoS22.to_csv('y_DDoS22.csv')
